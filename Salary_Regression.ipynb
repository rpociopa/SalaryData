# %%
# %pip install seaborn

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('Salary_dataset.csv')

# %%
# Examine dataset 1: Ask for Rows and Columns
df.shape
# Out:
# (30, 3)

# %%
# Examine dataset 2: List all Column Names
df.columns
# Out:
# Index(['Unnamed: 0', 'YearsExperience', 'Salary'], dtype='object')

# %%
# Examine dataset 3: Show the type of data in each column
df.dtypes
# Out:
# Unnamed: 0           int64
# YearsExperience    float64
# Salary             float64
# dtype: object

# %%
# Examine dataset 4: Return first 3 rows. "Unnamed" looks like a primary key/unique ID without a heading
df.head(3)
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0

# %%
# Examine Dataset 5: Basic info for all columns
df.info
# Out:
# <bound method DataFrame.info of     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
# Examine Dataset 5: Basic Statistics
df.describe().T
# Out:
#                  count          mean           std      min       25%  \
# Unnamed: 0        30.0     14.500000      8.803408      0.0      7.25
# YearsExperience   30.0      5.413333      2.837888      1.2      3.30
# Salary            30.0  76004.000000  27414.429785  37732.0  56721.75
#
#                      50%        75%       max
# Unnamed: 0          14.5      21.75      29.0
# YearsExperience      4.8       7.80      10.6
# Salary           65238.0  100545.75  122392.0

# %%
# Examine Dataset 6: Bring in matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Examine Dataset 7: Histograms for all columns. Need to find out how to get rid of Unnamed.
fig = plt.figure(figsize = (15,15))
ax = fig.gca()
g = df.hist(ax=ax)
# Out:
# <ipython-input-12-ce614d195482>:4: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   g = df.hist(ax=ax)

# %%
# Apply heatmap to look at correlation between Experience & Salary (obvious @ 0.98)
corr_matrix = df.corr()
top_corr_features = corr_matrix.index
plt.figure(figsize = (20,20))
sns.heatmap(data=df[top_corr_features].corr(), annot = True, cmap='RdYlGn')
# Out:
# <AxesSubplot:>
